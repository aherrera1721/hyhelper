# %%
import HyHelper as hh
# Out:
# All files imported successfully. Welcome to HyHelper!

# %%
traj_request = hh.traj_request('DR_test', (18.486, -69.933), [[2005],[1, 2], {1: [5], 2: [7]}, [0]], -120, alts = [500], get_reverse=True)
traj_dump = r'/Users/alexherrera/Desktop/'
files = hh.get_traj(traj_request, traj_dump)
# Out:
# Working on traj #: 1/2
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajtype.pl?runtype=archive
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajasrc.pl
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajsrcm.pl
# Currently at: https://www.ready.noaa.gov/hypub-bin/traj1.pl
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajresults.pl?jobidno=138817
# Working on traj #: 2/2
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajtype.pl?runtype=archive
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajasrc.pl
# Currently at: https://www.ready.noaa.gov/hypub-bin/trajsrcm.pl
# Currently at: https://www.ready.noaa.gov/hypub-bin/traj1.pl

# %%
traj1 = HyHelper.Traj('/Users/alexherrera/Desktop/DR_testm01d01y2005h00')
traj2 = HyHelper.Traj('/Users/alexherrera/Desktop/reversetraj/DR_testm01d01y2005h00REVERSE')
print(traj1, traj2)
# Out:
# Traj 'DR_testm01d01y2005h00' (121 points) Traj 'DR_testm01d01y2005h00REVERSE' (121 points)

# %%
plots = HyHelper.gen_plots([traj1, traj2], (18.486, -69.933))
